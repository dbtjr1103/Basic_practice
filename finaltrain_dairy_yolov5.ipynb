# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/finaltrain_dairy_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="SseYdmaNMk2zCfN7zILH")
project = rf.workspace("mainproject").project("dairy-dxldm")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dairy-1 in yolov5pytorch:: 100%|██████████| 2011/2011 [00:00<00:00, 2747.36it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15070, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 15070 (delta 26), reused 30 (delta 13), pack-reused 15019
# Receiving objects: 100% (15070/15070), 14.13 MiB | 20.79 MiB/s, done.
# Resolving deltas: 100% (10319/10319), done.
# /content/yolov5

# %%
# !pip install -qr requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.3 MB/s eta 0:00:00

# %%
import torch
import utils
from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download
# %cat /content/dairy-1/data.yaml
# Out:
# names:
# - "BR민트초코우유'
# - "BR베리베리스트로베리우유'
# - "BR이상한나라의솜사탕우유'
# - "BR쿠키앤크림우유'
# - "남양초코에몽250ML'
# - "네스퀵초코'
# - "닥터유단백질바나나'
# - "닥터유단백질초코'
# - "닥터유프로단백질초코250ml'
# - "닥터캡슐프로텍트베리믹스'
# - "닥터캡슐프로텍트사과'
# - "닥터캡슐프로텍트플레인'
# - "더단백초코'
# - "더단백카라멜'
# - "더단백커피'
# - "덴마크드링킹요구르트딸기'
# - "덴마크드링킹요구르트사과'
# - "덴마크드링킹요구르트샤인머스켓'
# - "덴마크드링킹요구르트플레인'
# - "덴마크딸기딸기'
# - "덴마크민트초코'
# - "덴마크바나나우유'
# - "덴마크얼라이브망고'
# - "덴마크얼라이브머스캣청포도'
# - "덴마크얼라이브블러드오렌지'
# - "덴마크얼라이브스위트자몽'
# - "덴마크초코초코'
# - "델몬트콜드오렌지'
# - "델몬트콜드포도'
# - "랩노쉬프로틴마일드라떼350ml'
# - "랩노쉬프로틴마일드카카오350ml'
# - "로스터리아메리카노'
# - "매일두유99.9'
# - "매일두유검은콩'
# - "매일두유오리지널'
# - "매일소화가잘되는우유오리지널락토프리'
# - "매일아몬드브리즈뉴트리플러스프로틴'
# - "매일우유속에딸기과즙'
# - "매일허쉬초콜릿드링크쿠키앤크림'
# - "바이오그레놀라'
# - "바이오초코링프로틴볼'
# - "비요뜨링크'
# - "비요뜨초코팝'
# - "빙그레딸기맛우유'
# - "빙그레바나나맛우유'
# - "빙그레바나나맛우유라이트'
# - "빙그레요플레프로틴고단백질요거트'
# - "서울우유'
# - "서울우유저지방'
# - "서울우유초콜릿'
# - "서울우유커피'
# - "셀렉스프로틴복숭아'
# - "셀렉스프로틴아메리카노'
# - "셀렉스프로틴초코'
# - "소와나무덴마크드링킹요구르트베리믹스'
# - "소와나무덴마크드링킹요구르트복숭아'
# - "소화가잘되는우유미숫가루'
# ...

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 200 --data /content/dairy-1/data.yaml --weights 'yolov5n.pt' --name yolov5n_results  --cache
# Out:
# /content/yolov5
# train: weights=yolov5n.pt, cfg=, data=/content/dairy-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5n_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-80-gc3c8e71 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 200 --data /content/dairy-1/data.yaml --weights 'yolov5s.pt' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=, data=/content/dairy-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-80-gc3c8e71 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/yolov5s_results/weights/best.pt --data /content/dairy-1/data.yaml --img 640
# Out:
# val: data=/content/dairy-1/data.yaml, weights=['/content/yolov5/runs/train/yolov5s_results/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7277128 parameters, 0 gradients, 16.6 GFLOPs
# val: Scanning /content/dairy-1/valid/labels.cache... 300 images, 0 backgrounds, 0 corrupt: 100% 300/300 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:03<00:00,  2.58it/s]
#                    all        300        485      0.941      0.972       0.99      0.921
# ...

# %%
# %%time
# %cd /content/yolov5/
# !python export.py  --weights /content/yolov5/runs/train/yolov5s_results/weights/best.pt  --include tflite
# Out:
# /content/yolov5
# export: data=data/coco128.yaml, weights=['/content/yolov5/runs/train/yolov5s_results/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7277128 parameters, 0 gradients, 16.6 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/yolov5s_results/weights/best.pt with output shape (1, 25200, 104) (56.2 MB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="x2g0cc9LVwtb4OuDYTFj")
project = rf.workspace("last-s46sz").project("drink-keffs")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to drink-1 in yolov5pytorch:: 100%|██████████| 7212/7212 [00:00<00:00, 7461.07it/s]

# %%
# %cat ./drink-1/data.yaml
# Out:
# names:
# - "CJ)새싹보리410ML"
# - "CJ컨디션헛개100ML"
# - "가야복숭아농장1-5L"
# - "가야알로에농장1-5L"
# - "가야토마토농장1-5L"
# - "가야토마토농장180ML"
# - "광동)발효홍삼100ml"
# - "광동)비타500(병)100ML"
# - "광동)알찬콩두유200ML"
# - "광동)옥수수수염차500ML"
# - "광동)힘찬하루헛개차1L"
# - "광동힘찬하루헛개차500ML"
# - "남양엣홈오렌지1-5L"
# - "델몬트허니애플시나몬280ML"
# - "동서TOP심플리스무스블랙240ML"
# - "동서TOP심플리스무스스위트아메리카노240ML"
# - "동아오츠카데미소다자몽250ML"
# - "동아오츠카마신다미네랄워터500ML"
# - "동아포카리스웨트500ML"
# - "동원시스템새벽헛개520ML"
# - "레쓰비그란데라떼500ML"
# - "롯데)델몬트듬뿍사과1L"
# - "롯데)술술풀리는하루작두콩차500ML"
# - "롯데)칸타타콘트라베이스(스위트블랙)500ML"
# - "롯데)콜드비타민플러스(포도)240ML"
# - "롯데)파머스주스바오렌지1L"
# - "롯데고려홍삼180ML"
# - "롯데레쓰비175ML"
# - "롯데마운틴듀355ML"
# - "롯데밀키스1-5L"
# - "롯데밀키스500ML"
# - "롯데사랑초톡톡스파클링330ML"
# - "롯데아이시스200ML"
# - "롯데옥수수수염차500ML"
# - "롯데잘빠진하루우엉차500ML"
# - "롯데칸타타아메리카노200ML"
# - "롯데칸타타카페모카(병)250ML"
# - "롯데클라우드클리어제로(캔)350ML"
# - "롯데핑크퐁오렌지망고235ML"
# - "롯데핫식스자몽250ML"
# - "루비키스트루비레드자몽1-89L"
# - "미닛메이드오리지널오렌지1-5L"
# - "빙그레)맑은하늘도라지차500ML"
# - "슈웹스레몬토닉350ML"
# - "신어산음료일화광천수500ML"
# - "썬키스트머스캣1-5L"
# ...

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 70 --data ./drink-1/data.yaml --weights 'yolov5s.pt' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=, data=./drink-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=70, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 50 (delta 30), reused 42 (delta 25), pack-reused 0
# Unpacking objects: 100% (50/50), 10.03 KiB | 604.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
#  * [new branch]      docker     -> origin/docker
# ...

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 10 --data ./drink-1/data.yaml --weights /content/yolov5/runs/train/yolov5s_results2/weights/best.pt --name yolov5s_results  --cache
# Out:
# /content/yolov5
# train: weights=/content/yolov5/runs/train/yolov5s_results2/weights/best.pt, cfg=, data=./drink-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# %%time
# %cd /content/yolov5/
# !python export.py  --weights /content/yolov5/runs/train/yolov5s_results3/weights/best.pt --include tflite
# Out:
# /content/yolov5
# export: data=data/coco128.yaml, weights=['/content/yolov5/runs/train/yolov5s_results3/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7277128 parameters, 0 gradients, 16.6 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/yolov5s_results3/weights/best.pt with output shape (1, 25200, 104) (14.3 MB)
# ...
