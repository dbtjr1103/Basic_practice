# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/%ED%81%AC%EB%A1%A4%EB%A7%81_%EB%8F%99%EC%A0%81%ED%8E%98%EC%9D%B4%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.google.com/search?q=%EA%B0%95%EC%95%84%EC%A7%80&biw=878&bih=1312&gbv=1&tbm=isch&sxsrf=ALiCzsbbTs8IYQsd4bqMDTQG-K_d996hqA:1667180777154&ei=6ShfY5-HCeHX2roPkoqSiA0&start=0&sa=N'

resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')
img_tags = soup.select('img.yWs4tf')
len(img_tags)
# Out:
# 20

# %%
img_tags[0]['src']
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQegk3SVvBGmKXkGScW_yOb2e35ROisQdzPU8Y77WCdiRIVSlWe068iYzwyjBc&s'

# %%
# !mkdir img_folder
# Out:
# mkdir: cannot create directory ‘img_folder’: File exists

# %%
for idx, img in enumerate(img_tags):
    img_src = img['src']
    resp = requests.get(img_src)

    img = resp.content

    with open('img_folder/img_{:02}.jpg'.format(idx), 'wb') as f:
        f.write(resp.content)

# %%
# # 10페이지에서 가져오기
# # url = 'https://www.google.com/search?q=%EA%B0%95%EC%95%84%EC%A7%80&biw=878&bih=1312&gbv=1&tbm=isch&sxsrf=ALiCzsbwOsGdtU5PnfJTciFkPRlKj9oALg:1667181951660&ei=fy1fY4D3J53j2roPvOq6kA0&start=0&sa=N'
# # pg = url.split('&')[-2].split('=')[-1]

# imgs_200 = []

# for i in range(0,201,20):
#     url_pg = 'https://www.google.com/search?q=%EA%B0%95%EC%95%84%EC%A7%80&biw=878&bih=1312&gbv=1&tbm=isch&sxsrf=ALiCzsZZZVH-981KVPu9LVYGvlj6by--mA:1667182005711&ei=tS1fY_qLK9nX2roPgN-E-Aw&start=' + str(i) + '0&sa=N'
#     resp = requests.get(url_pg)
#     soup = BeautifulSoup(resp.content)
#     imgs = soup.select('img.yWs4tf')

#     print(list(imgs['src']))
#     # imgs_200.append(list(imgs)['src'])


#     # for idx, img in enumerate(img_tags):
#     # img_src = img['src']
#     # resp = requests.get(img_src)

#     # img = resp.content

#     # with open('img_folder/img_{:02}.jpg'.format(idx), 'wb') as f:
#     #     f.write(resp.content)
# imgs_200

# %%
from tqdm.notebook import tqdm
# tqdm에 대한 설명 (desc='설명')
# 여러페이지 

for i in tqdm(range(10), desc='페이지'):
    # i = 0, 1, 2, 3
    # start = 0, 20, 40, 60
    start = 20*i
    url = 'https://www.google.com/search?q=%EA%B0%95%EC%95%84%EC%A7%80&hl=ko&gbv=1&biw=1280&bih=577&tbm=isch&sxsrf=ALiCzsbwaZdxp_qpN2ONgFlxSwo1KGciTw:1657845891787&ei=g7jQYv28L_e12roPuoa5sAU&start={}&sa=N'.format(start)
    resp = requests.get(url)

    soup = BeautifulSoup(resp.content, 'lxml')
    img_tags = soup.select('img.yWs4tf')
    len(img_tags)

    for idx, img_tag in tqdm(enumerate(img_tags), desc='이미지/페이지'):
        img_src = img_tag['src']
        resp_img = requests.get(img_src)

        img = resp_img.content

        with open('강아지_{:03}.jpg'.format(start+idx+1), 'wb') as f:
            f.write(img)
# Out:
# 페이지:   0%|          | 0/10 [00:00<?, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]

# %%
url = 'https://bluer.co.kr/api/v1/restaurants?page=0&size=30&query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng='
resp = requests.get(url)

# resp.content  # -> JSON

# %%
# import json

# # 1) JSON을 딕셔너리로 변환
# dic = json.loads(jsn)
# dic

# # json으로 변환  : json.dumps(dict)
# jsn = json.dumps(dic)
# jsn

# %%
# JSON vs Dict 차이
# dic의 text화 
'''dic이 문자열로 묶여있으면 json
'''
# Out:
# 'dic이 문자열로 묶여있으면 json\n'

# %% [markdown]
# #### result에서 아래항목 데이터 가져오기

# %%
# result['_embedded']['restaurants'][0]['headerInfo']['nameKR'] #가게명
# result['_embedded']['restaurants'][0]['headerInfo']['ribbonType']
# result['_embedded']['restaurants'][0]['defaultInfo']['website']
# result['_embedded']['restaurants'][0]['defaultInfo']['phone']
# result['_embedded']['restaurants'][0]['defaultInfo']['dayOff']
# result['_embedded']['restaurants'][0]['statusInfo']['parking']
# result['_embedded']['restaurants'][0]['statusInfo']['priceRange']
# result['_embedded']['restaurants'][0]['statusInfo']['menu']
# result['_embedded']['restaurants'][0]['statusInfo']['businessHours']

# %%
import json 
import requests

# blue_info = {
#     '가게명' : [],
#     '리본등급' : [],
#     "사이트" : [], 
#     "전화번호": [], 
#     "휴무": [],
#     "주차":[],
#     "가격범위":[],
#     "메뉴":[],
#     "영업시간":[]
# }
url = 'https://bluer.co.kr/api/v1/restaurants?page=0&size=30&query=&foodType=&foodTypeDetail=&feature=&location=&locationDetail=&area=&areaDetail=&priceRange=&ribbonType=&recommended=false&isSearchName=false&tabMode=single&searchMode=ribbonType&zone1=&zone2=&zone2Lat=&zone2Lng='
resp = requests.get(url)

result = json.loads(resp.content)

names, ribbons, sites, tels, dayoffs, parks, prices, menus, times = [], [], [], [], [], [], [], [], []

# %%
restaurants = result['_embedded']['restaurants']

for restaurant in restaurants:
    names.append(restaurant['headerInfo']['nameKR'])
    ribbons.append(restaurant['headerInfo']['ribbonType'])
    sites.append(restaurant['defaultInfo']['website'])
    tels.append(restaurant['defaultInfo']['phone'])
    dayoffs.append(restaurant['defaultInfo']['dayOff'])
    parks.append(restaurant['statusInfo']['parking'])
    prices.append(restaurant['statusInfo']['priceRange'])
    menus.append(restaurant['statusInfo']['menu'])
    times.append(restaurant['statusInfo']['businessHours'])

blue_info = {
    '가게명' : names,
    '리본등급' : ribbons,
    "사이트" : sites, 
    "전화번호": tels, 
    "휴무": dayoffs,
    "주차": parks,
    "가격범위": prices,
    "메뉴": menus,
    "영업시간": times
}

# %%
import pandas as pd

df_blue = pd.DataFrame(blue_info)
df_blue
# Out:
#          가게명          리본등급                                                사이트  \
# 0        권숙수  RIBBON_THREE                             http://kwonsooksoo.com
# 1         낙원  RIBBON_THREE  http://mayfield.co.kr/2017/kor/html/restaurant...
# 2       다이닝마  RIBBON_THREE                                 http://diningma.kr
# 3     더그린테이블  RIBBON_THREE                        http://thegreentable.co.kr/
# 4         도림  RIBBON_THREE  http://www.lottehotel.com/seoul/ko/dining/rest...
# 5         도원  RIBBON_THREE  https://www.hoteltheplaza.com/kr/dining/taoyue...
# 6      라망시크레  RIBBON_THREE
# 7       라미띠에  RIBBON_THREE                           http://lamitie.modoo.at/
# 8         라연  RIBBON_THREE  https://www.shilla.net/seoul/dining/viewDining...
# 9    레스쁘아뒤이부  RIBBON_THREE
# 10      모모야마  RIBBON_THREE  http://www.lottehotel.com/seoul/ko/dining/dini...
# 11      모수서울  RIBBON_THREE                               http://mosuseoul.com
# ...

# %%
# js에서 가져오기
url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_cv=20221018144728&_callback=jQuery112401786210816863696_1667194800949&lang=ko&country=KR&objectId=801827_1&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&userType=&useAltSort=true&replyPageSize=10&_=1667194800951'

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
    'referer' : 'https://comic.naver.com/comment/comment?titleId=801827&no=1' # 참조값(소개)
}

resp = requests.get(url, headers=headers)
result = resp.text  # 403 오류 요청 거절당함
# json.loads()사용하려면 맨앞 : jQuery 1y1972t172391823 / 맨 뒤 ); 가 없어야지 가능 
result
# Out:
# 'jQuery112401786210816863696_1667194800949({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"commentList":[{"ticket":"comic","objectId":"801827_1","categoryId":"*","templateId":"default_v2","commentNo":"446434067","parentCommentNo":"446434067","replyLevel":1,"replyCount":7,"replyAllCount":7,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1667135978447,"contents":"얼굴이 잘생겨 진거 보면 역시 남자는 머리빨","userIdNo":"d00fD","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"seo","userProfileImage":"https://profile-phinf.pstatic.net/39565/33946c1de274d49eddfe2fcffa5b2c8a3a766eb1de406ec1ea6eebb0a42f9152.jpg","profileType":"naver","modTime":"2022-10-30T22:19:38+0900","modTimeGmt":"2022-10-30T13:19:38+0000","regTime":"2022-10-30T22:19:38+0900","regTimeGmt":"20
# ...

# %%
result  = result.replace('jQuery112401786210816863696_1667194800949(', '')[:-2]
result = json.loads(result)
result
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'comic',
#     'objectId': '801827_1',
#     'categoryId': '*',
#     'templateId': 'default_v2',
#     'commentNo': '446434067',
#     'parentCommentNo': '446434067',
#     'replyLevel': 1,
#     'replyCount': 7,
#     'replyAllCount': 7,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1667135978447,
#     'contents': '얼굴이 잘생겨 진거 보면 역시 남자는 머리빨',
#     'userIdNo': 'd00fD',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'seo',
# ...

# %%
result['result']['commentList']
# Out:
# [{'ticket': 'comic',
#   'objectId': '801827_1',
#   'categoryId': '*',
#   'templateId': 'default_v2',
#   'commentNo': '446434067',
#   'parentCommentNo': '446434067',
#   'replyLevel': 1,
#   'replyCount': 7,
#   'replyAllCount': 7,
#   'replyPreviewNo': None,
#   'replyList': None,
#   'imageCount': 0,
#   'imageList': None,
#   'imagePathList': None,
#   'imageWidthList': None,
#   'imageHeightList': None,
#   'commentType': 'txt',
#   'stickerId': None,
#   'sticker': None,
#   'sortValue': 1667135978447,
#   'contents': '얼굴이 잘생겨 진거 보면 역시 남자는 머리빨',
#   'userIdNo': 'd00fD',
#   'exposedUserIp': None,
#   'lang': 'ko',
#   'country': 'KR',
#   'idType': 'naver',
#   'idProvider': 'naver',
#   'userName': 'seo',
#   'userProfileImage': 'https://profile-phinf.pstatic.net/39565/33946c1de274d49eddfe2fcffa5b2c8a3a766eb1de406ec1ea6eebb0a42f9152.jpg',
#   'profileType': 'naver',
#   'modTime': '2022-10-30T22:19:38+0900',
#   'modTimeGmt': '2022-10-30T13:19:38+0000',
# ...

# %%
# 전체 댓글의 맨 뒷페이지 번호 가져오기
url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?'

params = {
    'ticket' : 'comic',
    'templateld' : 'webtoon',
    'pool' : 'cbox3',
    '_cv' : '20221018144728',
    '_callback' : '',
    'lang' : 'ko',  
    'country' : 'KR',  
    'objectId' : '783053_52', # 웹툰의 고유 아이디_해당화 인덱스  
    'pageSize' : 15,  
    'indexSize' : 10,  
    'listType' : 'OBJECT',  
    'pageType' : 'default',  
    'page' : 1, # 전체댓글의 페이지 번호 
    'refresh' : 'true',  
    'sort' : 'BEST' # 전체댓글 URL의 고유 쿼리 
    }

headers = {
    'referer': 'https://comic.naver.com/comment/comment?titleId=783053&no=52',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

resp = requests.get(url, params=params, headers=headers)

resp.text
# Out:
# '_callback({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"commentList":[{"ticket":"comic","objectId":"783053_52","categoryId":"*","templateId":"default_v2","commentNo":"444588718","parentCommentNo":"444588718","replyLevel":1,"replyCount":306,"replyAllCount":334,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1663595880447,"contents":"정답: 교육부!","userIdNo":"ey99F","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"082","userProfileImage":"https://profile-phinf.pstatic.net/33344/229b0d5f34a408cfe79790c9fcadb1ad78b13f71570d482c4ce3d12f7d4fbf03.jpg","profileType":"naver","modTime":"2022-09-19T22:58:00+0900","modTimeGmt":"2022-09-19T13:58:00+0000","regTime":"2022-09-19T22:58:00+0900","regTimeGmt":"2022-09-19T13:58:00+0000","sympathyCount":139
# ...

# %%
len('_callback(')
# Out:
# 10

# %%
jsn = resp.text[10:-2]
dict_resp = json.loads(jsn)
dict_resp
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'comic',
#     'objectId': '783053_52',
#     'categoryId': '*',
#     'templateId': 'default_v2',
#     'commentNo': '444588718',
#     'parentCommentNo': '444588718',
#     'replyLevel': 1,
#     'replyCount': 306,
#     'replyAllCount': 334,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1663595880447,
#     'contents': '정답: 교육부!',
#     'userIdNo': 'ey99F',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '082',
# ...

# %%
reviews = {
    '댓글' : [],
    '공감수' : [],
    '비공감수' : []
}
commentList = dict_resp['result']['commentList']
# len(commentList)

for comment in commentList:
    reviews['댓글'].append(comment['contents'])
    reviews['공감수'].append(comment['sympathyCount'])
    reviews['비공감수'].append(comment['antipathyCount'])

# %%
df_reviews = pd.DataFrame(reviews)
df_reviews
# Out:
#                                         댓글    공감수  비공감수
# 0                                 정답: 교육부!  13992   136
# 1                                포골 한칸 더 ?   8717    55
# 2   자유를 억압하고 본인들의 바람만을 원하고 강요하는 학부모들을 말하는듯   3376    56
# 3             뭐긴 뭐야 롤이지\n\n내가 오늘도 몇번을 죽었는데   3354    48
# 4                              정답 : 한라인만 더   1702    28
# 5                             "사람들에게 잊혀질때"   1608    25
# 6                     정답 : 눈나\n헤으응 눈나 나 죽어   1064    51
# 7              ㅋㅋㅋ차에서 지루하다고 아저씨랑 넌센스퀴즈놀이하노    661    16
# 8                                      펜ㅌ닐    635    34
# 9                                정답. 카페맘클럽    519    24
# 10                       청소년 자살율 자살원인 말하는듯    460    18
# 11    정답: 킥보드 이바리 삼바리 노뚝에 거의뭐 죽인게 아니라 자살이지    421    18
# 12                        정답 : 눈나\n눈나 나 죽어    401    33
# 13            정답이 교육부라고? 서태지 교실 이데아 가 아니고?    399    43
# 14                                자살 말하는건가    389    17

# %%
# 한 화 전체댓글
# 모든 화 베스트 댓글
# 모든 화 전체 댓글
# 모든 웹툰 최신화의 베스트 댓글

# %%
dict_resp['result']
# Out:
# {'commentList': [{'ticket': 'comic',
#    'objectId': '783053_52',
#    'categoryId': '*',
#    'templateId': 'default_v2',
#    'commentNo': '446459302',
#    'parentCommentNo': '446459302',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1667199748212,
#    'contents': '???:모기 아니냐',
#    'userIdNo': '22T9r',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': '선영이',
#    'userProfileImage': 'https://profile-phinf.pstatic.net/05414/7ce5711dc4829e67368ca9990d1c23876e61ab73bbc44d776f43c004c6db95d1.jpg',
#    'profileType': 'naver',
#    'modTime': '2022-10-31T16:02:28+0900',
# ...

# %%
# 원하는 웹툰 전체화의 전체댓글 / 베스트 댓글 가져오기
import json 
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import pandas as pd

# %%
url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_cv=20221018144728&_callback=jQuery112409767973216970143_1667194741406&lang=ko&country=KR&objectId=783053_52&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&userType=&useAltSort=true&replyPageSize=10&_=1667194741408'

headers = {
        'referer': 'https://comic.naver.com/comment/comment?titleId=783053&no=52',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

resp = requests.get(url, headers=headers)
result = resp.text

# %%
result
# Out:
# 'jQuery112409767973216970143_1667194741406({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"commentList":[{"ticket":"comic","objectId":"783053_52","categoryId":"*","templateId":"default_v2","commentNo":"444588718","parentCommentNo":"444588718","replyLevel":1,"replyCount":306,"replyAllCount":336,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1663595880447,"contents":"정답: 교육부!","userIdNo":"ey99F","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"082","userProfileImage":"https://profile-phinf.pstatic.net/33344/229b0d5f34a408cfe79790c9fcadb1ad78b13f71570d482c4ce3d12f7d4fbf03.jpg","profileType":"naver","modTime":"2022-09-19T22:58:00+0900","modTimeGmt":"2022-09-19T13:58:00+0000","regTime":"2022-09-19T22:58:00+0900","regTimeGmt":"2022-09-19T13
# ...

# %%
result = result.replace('jQuery112409767973216970143_1667194741406(', '')[:-2]
result = json.loads(result)
result
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'comic',
#     'objectId': '783053_52',
#     'categoryId': '*',
#     'templateId': 'default_v2',
#     'commentNo': '444588718',
#     'parentCommentNo': '444588718',
#     'replyLevel': 1,
#     'replyCount': 306,
#     'replyAllCount': 336,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1663595880447,
#     'contents': '정답: 교육부!',
#     'userIdNo': 'ey99F',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '082',
# ...

# %%
#'result' 'commentList'  [] 'contents'
                            # 'sympathyCount': 13976,
                            # 'antipathyCount': 136,
contents, syms, antis = [], [], []

commentList = result['result']['commentList']

for comment in commentList:
    contents.append(comment['contents'])
    syms.append(comment['sympathyCount'])
    antis.append(comment['antipathyCount'])
contents, syms, antis
# Out:
# (['정답: 교육부!',
#   '포골 한칸 더 ?',
#   '뭐긴 뭐야 롤이지\n\n내가 오늘도 몇번을 죽었는데',
#   '자유를 억압하고 본인들의 바람만을 원하고 강요하는 학부모들을 말하는듯',
#   '정답 : 한라인만 더',
#   '"사람들에게 잊혀질때"',
#   '정답 : 눈나\n헤으응 눈나 나 죽어',
#   'ㅋㅋㅋ차에서 지루하다고 아저씨랑 넌센스퀴즈놀이하노',
#   '펜ㅌ닐',
#   '정답. 카페맘클럽',
#   '청소년 자살율 자살원인 말하는듯',
#   '정답: 킥보드 이바리 삼바리 노뚝에 거의뭐 죽인게 아니라 자살이지',
#   '정답 : 눈나\n눈나 나 죽어',
#   '정답이 교육부라고? 서태지 교실 이데아 가 아니고?',
#   '자살 말하는건가'],
#  [14181,
#   8845,
#   3439,
#   3427,
#   1738,
#   1650,
#   1104,
#   683,
#   646,
#   532,
#   471,
#   430,
#   408,
#   407,
#   395],
#  [138, 56, 49, 56, 28, 27, 52, 16, 34, 24, 18, 18, 33, 43, 17])

# %%
dic = {
    '댓글' : contents,
    '공감수' : syms,
    '비공감수' : antis
}
df_dic = pd.DataFrame(dic)
df_dic
# Out:
#                                         댓글    공감수  비공감수
# 0                                 정답: 교육부!  14181   138
# 1                                포골 한칸 더 ?   8845    56
# 2             뭐긴 뭐야 롤이지\n\n내가 오늘도 몇번을 죽었는데   3439    49
# 3   자유를 억압하고 본인들의 바람만을 원하고 강요하는 학부모들을 말하는듯   3427    56
# 4                              정답 : 한라인만 더   1738    28
# 5                             "사람들에게 잊혀질때"   1650    27
# 6                     정답 : 눈나\n헤으응 눈나 나 죽어   1104    52
# 7              ㅋㅋㅋ차에서 지루하다고 아저씨랑 넌센스퀴즈놀이하노    683    16
# 8                                      펜ㅌ닐    646    34
# 9                                정답. 카페맘클럽    532    24
# 10                       청소년 자살율 자살원인 말하는듯    471    18
# 11    정답: 킥보드 이바리 삼바리 노뚝에 거의뭐 죽인게 아니라 자살이지    430    18
# 12                        정답 : 눈나\n눈나 나 죽어    408    33
# 13            정답이 교육부라고? 서태지 교실 이데아 가 아니고?    407    43
# 14                                자살 말하는건가    395    17

# %%
# 하나의 웹툰, 하나의 화 전체댓글
# 전체 댓글의 맨 뒤페이지 번호 가져오기
url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?'

params ={
        'ticket' : 'comic',  
        'templateId' : 'webtoon',  
        'pool' : 'cbox3',  
        '_callback' : '', # jQuery112409091552467251651_1615854232166 -> ''  
        'lang' : 'ko',  
        'country' : 'KR',  
        'objectId' : '783053_52', # 웹툰의 고유 아이디_해당화 인덱스  
        'pageSize' : 15,  
        'indexSize' : 10,  
        'listType' : 'OBJECT',  
        'pageType' : 'default',  
        'page' : 1, # 전체댓글의 페이지 번호 
        'refresh' : 'true',  
        'sort' : 'NEW' # 전체댓글 URL의 고유 쿼리 
        }

headers = {
        'referer': 'https://comic.naver.com/comment/comment.nhn?titleId=650305&no=298',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'

}

resp = requests.get(url, params=params, headers=headers)
 
resp
# Out:
# <Response [200]>

# %%
result = json.loads(resp.text[10:-2]) # resp.text[10:-2] -> { ~~~~~ } 
result
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'comic',
#     'objectId': '783053_52',
#     'categoryId': '*',
#     'templateId': 'default_v2',
#     'commentNo': '446486426',
#     'parentCommentNo': '446486426',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1667253689047,
#     'contents': '설마 죽겠냐 ㅋㅋ',
#     'userIdNo': 'cPrfF',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '맨시 수호자',
# ...

# %%
totalPages = result['result']['pageModel']['totalPages']
totalPages
# Out:
# 93

# %%
# best 댓글
# url  :  'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery112408122866196452874_1612750131447&lang=ko&country=KR&objectId=650305_298&pageSize=15&indexSize=10&listType=OBJECT&pageType=default&page=1&initialize=true&useAltSort=true&replyPageSize=10&_=1612750131448'
webtoon = {
        'index' : [],
        '댓글' : [],
        '공감수' : [],
        '비공감수' :[]
        }

# 전체 댓글
url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?'

for page in tqdm(range(1, totalPages+1)):
    params ={
            'ticket' : 'comic',  
            'templateId' : 'webtoon',  
            'pool' : 'cbox3',  
            '_callback' : '',  
            'lang' : 'ko',  
            'country' : 'KR',  
            'objectId' : '650305_298', # 웹툰의 고유 아이디_해당화 인덱스  
            'pageSize' : 15,  
            'indexSize' : 10,  
            'listType' : 'OBJECT',  
            'pageType' : 'default',  
            'page' : page, # 전체댓글의 페이지 번호 
            'refresh' : 'true',  
            'sort' : 'NEW', # 전체댓글 URL의 고유 쿼리 
            '_' : 1612753212403
            }

    headers = {
        'referer': 'https://comic.naver.com/comment/comment.nhn?titleId=650305&no=298',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'
    }

    resp = requests.get(url, params=params, headers=headers)


    result = json.loads(resp.text[10:-2])
    result
    # result commentList : [] 'antipathyCount', 'contents', 'commentNo', 'sympathyCount'

    commentList = result['result']['commentList']

    for comment in commentList:
        webtoon['index'].append(comment['commentNo'])
        webtoon['댓글'].append(comment['contents'])
        webtoon['공감수'].append(comment['sympathyCount'])
        webtoon['비공감수'].append(comment['antipathyCount'])
# Out:
#   0%|          | 0/93 [00:00<?, ?it/s]

# %%
df_webtoon = pd.DataFrame(webtoon)
df_webtoon
# Out:
#           index                                                 댓글  공감수  비공감수
# 0     446117671  무커 생각나서 더 슬프네.. 캐릭터 하나하나가 다 사연이 있어서 더 짠함.. 다같이...    1     0
# 1     445811468                                                 5타    0     0
# 2     445646012      이렇게 재밌고 감동적인데 요즘나오는 장면들은 왜 다 이모양인지 같은 작가 맞는건가    0     3
# 3     444661981                             숨바꼭질 안할래 하는거 왜이리 마음아프냐    6     0
# 4     444557937                                이구덩이가 완달vs흑룡 결과물이구나    0     0
# ...         ...                                                ...  ...   ...
# 1390  407493322  마지막을 직감하는듯한 느낌이네요 추이가 죽음을 맞이할듯싶어요...   무커의 혼이 ...    7     0
# 1391  407493229                                    작가님들 항상 응원합니다^^    1     0
# 1392  407493180  시들이 산군이 있는 데로 도망 가서 추이가 산군을 보게 되고 이령이 얼음굴로 오고 ...    5     1
# 1393  407493169  작가님 제발 다음편만 주세요 그럼 다음주는 안올라오는데 다음주 참을게요 제발 다음편...    4     0
# 1394  407493159                             너희 대장님을 이령놈이 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ    3     0
#
# [1395 rows x 4 columns]

# %%
df_webtoon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   1395 non-null   object
#  1   댓글      1395 non-null   object
#  2   공감수     1395 non-null   int64
#  3   비공감수    1395 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 43.7+ KB

# %%
df_webtoon[df_webtoon['공감수'] >= 15]
# Out:
#           index                                                 댓글  공감수  비공감수
# 79    425487920                   무케 "숨바꼭질 안 할래"라고 하는 부분 겁나 짠하네...   17     0
# 119   416700438                               무케가 저렇게 배시시 웃는거 처음봤네   17     0
# 130   414998186                           무케 숨바꼭질 안할래...왤케 슬프냐....   15     0
# 133   414468019  숨바꼭질 안할래에서 눈물 흘렸다.. 무케가 천진난만하고 밝게 보여도 결국 부모의 품...   33     1
# 151   412359937  넘 슬프다ㅜ 무케 저 어린것이 아빤 줄 알고 대롱거리며 옹알대는것도 그런 무케 잠꼬...   19     0
# ...         ...                                                ...  ...   ...
# 1368  407495440  추이가 안죽었으면 좋겠지만 작가님만의 생각이\n있으실겁니다 이대로 추이가죽는지 아니...   43     3
# 1379  407494628                                  숨바꼭질 안할래 슬퍼ㅠㅠㅠㅠㅠㅜ   16     0
# 1383  407493961      왜 아저씨'들'인가했더니 생각해보니 추이가 정신없을때 태워버린 나주가 있구나...   26     1
# 1384  407493848  추이 이빨 들어내고 있는 실루엣\n\n무케에게 미안해서 울음을 참고 있는건지\n\n...   20     2
# 1389  407493354  무케가 추이에게서 아빠냄새가 난다하고 아빠냄새에서 아저씨 냄새가 난다고 다시 말할때...   25     1
#
# [119 rows x 4 columns]

# %%
# 하나의 웹툰, 전체 화
# 화 인덱스 포함해서 저장 

reviews = {
    '댓글' : [],
    '공감수' : [],
    '비공감수' : [],
    '화' : []
}

# %%
last_no = 26
for no in tqdm(range(1, last_no+1)):
    url = 'https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?'


    params ={
            'ticket' : 'comic',  
            'templateId' : 'webtoon',  
            'pool' : 'cbox3',  
            '_callback' : 'jQuery11240590927015056502_1658103118387', # jQuery112409091552467251651_1615854232166 -> ''  
            'lang' : 'ko',  
            'country' : 'KR',  
            'objectId' : '795487_{}'.format(no), # 웹툰의 고유 아이디_해당화 인덱스  
            'pageSize' : 15,  
            'indexSize' : 10,  
            'listType' : 'OBJECT',  
            'pageType' : 'default',  
            'page' : 1, # 전체댓글의 페이지 번호 
            'refresh' : 'true',  
            }

    headers = {
            'referer': 'https://comic.naver.com/comment/comment.nhn?titleId=650305&no=298',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'
    }

    resp = requests.get(url, params=params, headers=headers)
    
    jsn = resp.text[41:-2]

    dict_resp = json.loads(jsn)

    commentList = dict_resp['result']['commentList']
    # len(commentList)

    for comment in commentList:
        reviews['댓글'].append(comment['contents'])
        reviews['공감수'].append(comment['sympathyCount'])
        reviews['비공감수'].append(comment['antipathyCount'])
        reviews['화'].append(no)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]

# %%
df_reviews = pd.DataFrame(reviews)
df_reviews
# Out:
#                                                     댓글    공감수  비공감수   화
# 0                              이런 식이면 조금은 싸워도 괜찮지 않을까?  25375    42   1
# 1                            유연아.. 너의 태평양 같은 어깨는 여전하구나  23103    68   1
# 2                                          어떡해 더 잘생겨졌어  18275    43   1
# 3                                              와 미친 언니  16041    36   1
# 4                                  바름이 장발 너무 예뻐 물론 단발도  12306    30   1
# ..                                                 ...    ...   ...  ..
# 385                  아니야 신비야 아니야...!!!!!\n\n\n\n내가 할거야   3293     1  26
# 386  ㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아놔 작가님표 개그 오랜만에 보니까 광대가 막 씰룩거려옄ㅋㅋ...   3249     2  26
# 387                         신비 치킨 줍고있는거 너무 귀엽다ㅋㅋㅋㅋㅋㅋㅋㅋ   3211     2  26
# 388        아니 근데 지랑 남사친이랑 남친이랑 치킨처먹는데 남사친한테 닭다리를 준다고?    3070    99  26
# 389                                           가치 드실레예?   3014     2  26
#
# [390 rows x 4 columns]

# %%
df_reviews[df_reviews['공감수'] >= 15000]
# Out:
#                                                     댓글    공감수  비공감수   화
# 0                              이런 식이면 조금은 싸워도 괜찮지 않을까?  25375    42   1
# 1                            유연아.. 너의 태평양 같은 어깨는 여전하구나  23103    68   1
# 2                                          어떡해 더 잘생겨졌어  18275    43   1
# 3                                              와 미친 언니  16041    36   1
# 30                                  충격적이다못해 나도 능력 생길 듯  17075    25   3
# 45                                         그건 깻잎 전쟁이잖아  25309    18   4
# 46          명심하겠다니\n제야 이미 속으로는 100일 커플링 도안\n짜고있는거 아니야?  16401    17   4
# 60                                    와 진짜 fox는 역시 다르다  20266    20   5
# 61                         완결한지 몇년이 지나도 유명한웹툰은 나오는구나..  16401    27   5
# 75                                                놀고있네  18920    61   6
# 90                                                  가능  22248    25   7
# 91   춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배! 춘배...  18088    30   7
# ...
